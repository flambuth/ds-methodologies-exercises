# %%
# %matplotlib inline
from pydataset import data

import pyspark
import pyspark.ml
from pyspark.sql.functions import *

spark = pyspark.sql.SparkSession.builder.getOrCreate()

# %%
import wrangle

# %%
df = wrangle.wrangle_311(spark)
# Out:
# [wrangle.py] reading case.csv
# [wrangle.py] handling data types
# [wrangle.py] parsing dates
# [wrangle.py] adding features
# [wrangle.py] joining departments

# %%
df.dtypes
# Out:
# [('case_id', 'int'),
#  ('case_opened_date', 'timestamp'),
#  ('case_closed_date', 'timestamp'),
#  ('case_due_date', 'timestamp'),
#  ('case_late', 'boolean'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'boolean'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'string'),
#  ('num_weeks_late', 'double'),
#  ('zipcode', 'string'),
#  ('case_age', 'int'),
#  ('days_to_closed', 'int'),
#  ('case_lifetime', 'int'),
#  ('department', 'string'),
#  ('dept_subject_to_SLA', 'boolean')]

# %% [markdown]
# Use the .randomSplit method to split the 311 data into training and test sets.

# %%
#Apparently spark objects have a method that does the train/test split. 
train, test = df.randomSplit([0.75, 0.25], seed=420)

# %% [markdown]
# Create a classification model to predict whether a case will be late or not (i.e. predict case_late). Experiment with different combinations of features and different classification algorithms.

# %%
#RF is a Model that makes RDDs ready for Spark-MachineLearning alogrithms. It is:
#  1 instantiated when it is called from its class: pyspark.ml.feature
#  2 it is fitted to the data. this will generate the Labelpoints that get attached in the transform() step.
#       LabelPoint(features/target)tacked to the end of the RDD. 2 columns. Feature array and target variable
#  3 This Model that has been fitted has a .transform() method. It will be assigned to a new variable.
rf = pyspark.ml.feature.RFormula(formula='case_late ~ department + council_district').fit(train)

# %%
#train_input is another spark dataframe
train_input = rf.transform(train)

# %%
type(train_input)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
train_input.show(33, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  case_id              | 1014127333
#  case_opened_date     | 2018-01-01 00:46:00
#  case_closed_date     | 2018-01-03 08:11:00
#  case_due_date        | 2018-01-05 08:30:00
#  case_late            | false
#  num_days_late        | -2.0126041669999997
#  case_closed          | true
#  service_request_type | Removal Of Obstru...
#  SLA_days             | 4.322222222
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 2215  GOLIAD RD, ...
#  council_district     | 003
#  num_weeks_late       | -0.28751488099999994
#  zipcode              | 78223
#  case_age             | 219
#  days_to_closed       | 2
#  case_lifetime        | 2
#  department           | Trans & Cap Impro...
#  dept_subject_to_SLA  | true
#  features             | (17,[3,10],[1.0,1...
#  label                | 0.0
# -RECORD 1------------------------------------
#  case_id              | 1014127334
#  case_opened_date     | 2018-01-01 00:48:00
#  case_closed_date     | 2018-01-02 07:57:00
#  case_due_date        | 2018-01-05 08:30:00
#  case_late            | false
#  num_days_late        | -3.022337963
#  case_closed          | true
#  service_request_type | Removal Of Obstru...
#  SLA_days             | 4.320729167
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 102  PALFREY ST W...
#  council_district     | 003
#  num_weeks_late       | -0.43176256614285713
#  zipcode              | 78223
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | Trans & Cap Impro...
#  dept_subject_to_SLA  | true
#  features             | (17,[3,10],[1.0,1...
#  label                | 0.0
# -RECORD 2------------------------------------
#  case_id              | 1014127335
#  case_opened_date     | 2018-01-01 01:29:00
#  case_closed_date     | 2018-01-02 08:13:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -15.01148148
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.29188657
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 114  LA GARDE ST,...
#  council_district     | 003
#  num_weeks_late       | -2.1444973542857144
#  zipcode              | 78223
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,10],[1.0,1...
#  label                | 0.0
# -RECORD 3------------------------------------
#  case_id              | 1014127336
#  case_opened_date     | 2018-01-01 01:34:00
#  case_closed_date     | 2018-01-01 13:29:00
#  case_due_date        | 2018-01-01 04:34:00
#  case_late            | true
#  num_days_late        | 0.37216435200000003
#  case_closed          | true
#  service_request_type | Animal Cruelty(Cr...
#  SLA_days             | 0.125
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 734  CLEARVIEW DR...
#  council_district     | 007
#  num_weeks_late       | 0.053166336
#  zipcode              | 78228
#  case_age             | 219
#  days_to_closed       | 0
#  case_lifetime        | 0
#  department           | Animal Care Services
#  dept_subject_to_SLA  | true
#  features             | (17,[2,13],[1.0,1...
#  label                | 1.0
# -RECORD 4------------------------------------
#  case_id              | 1014127337
#  case_opened_date     | 2018-01-01 06:28:00
#  case_closed_date     | 2018-01-01 14:38:00
#  case_due_date        | 2018-01-31 08:30:00
#  case_late            | false
#  num_days_late        | -29.74398148
#  case_closed          | true
#  service_request_type | Traffic Signal Op...
#  SLA_days             | 30.08446759
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | BANDERA RD and BR...
#  council_district     | 007
#  num_weeks_late       | -4.249140211428571
#  zipcode              |
#  case_age             | 219
#  days_to_closed       | 0
#  case_lifetime        | 0
#  department           | Trans & Cap Impro...
#  dept_subject_to_SLA  | true
#  features             | (17,[3,13],[1.0,1...
#  label                | 0.0
# -RECORD 5------------------------------------
#  case_id              | 1014127338
#  case_opened_date     | 2018-01-01 06:57:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70673611
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06429398
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 004
#  num_weeks_late       | -2.1009623014285714
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 6------------------------------------
#  case_id              | 1014127339
#  case_opened_date     | 2018-01-01 06:58:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70662037
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.063796300000003
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 004
#  num_weeks_late       | -2.100945767142857
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 7------------------------------------
#  case_id              | 1014127340
#  case_opened_date     | 2018-01-01 06:58:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70662037
#  case_closed          | true
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.06333333
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 004
#  num_weeks_late       | -2.100945767142857
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 8------------------------------------
#  case_id              | 1014127343
#  case_opened_date     | 2018-01-01 07:02:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70636574
#  case_closed          | true
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.06104167
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 004
#  num_weeks_late       | -2.1009093914285715
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 9------------------------------------
#  case_id              | 1014127344
#  case_opened_date     | 2018-01-01 07:02:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70625
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06059028
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 004
#  num_weeks_late       | -2.100892857142857
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 10-----------------------------------
#  case_id              | 1014127345
#  case_opened_date     | 2018-01-01 07:03:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70636574
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06011574
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 004
#  num_weeks_late       | -2.1009093914285715
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 11-----------------------------------
#  case_id              | 1014127346
#  case_opened_date     | 2018-01-01 07:04:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70623843
#  case_closed          | true
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.05953704
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 004
#  num_weeks_late       | -2.1008912042857144
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 12-----------------------------------
#  case_id              | 1014127347
#  case_opened_date     | 2018-01-01 07:04:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.705891199999998
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05907407
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 004
#  num_weeks_late       | -2.1008416
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 13-----------------------------------
#  case_id              | 1014127348
#  case_opened_date     | 2018-01-01 07:05:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70600694
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 30-----------------------------------
#  case_id              | 1014127372
#  case_opened_date     | 2018-01-01 07:21:00
#  case_closed_date     | 2018-01-02 15:23:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.71255787
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.04744213
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 928  MARBLE POINT...
#  council_district     | 004
#  num_weeks_late       | -2.1017939814285715
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 31-----------------------------------
#  case_id              | 1014127373
#  case_opened_date     | 2018-01-01 07:22:00
#  case_closed_date     | 2018-01-02 15:24:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.71243056
#  case_closed          | true
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.04696759
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 928  MARBLE POINT...
#  council_district     | 004
#  num_weeks_late       | -2.101775794285714
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# -RECORD 32-----------------------------------
#  case_id              | 1014127374
#  case_opened_date     | 2018-01-01 07:23:00
#  case_closed_date     | 2018-01-02 15:24:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.71231481
#  case_closed          | true
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.04648148
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 928  MARBLE POINT...
#  council_district     | 004
#  num_weeks_late       | -2.1017592585714286
#  zipcode              | 78251
#  case_age             | 219
#  days_to_closed       | 1
#  case_lifetime        | 1
#  department           | DSD/Code Enforcement
#  dept_subject_to_SLA  | true
#  features             | (17,[0,11],[1.0,1...
#  label                | 0.0
# only showing top 33 rows

# %%
#Now that the training data is ready for spark-ML, we will do the 1-2-3 steps using Spark algorithms.
#Step 1
lr = pyspark.ml.classification.LogisticRegression()

# %%
type(lr)
# Out:
# pyspark.ml.classification.LogisticRegression

# %%
#Step 2. SKlearn lets you keep the model after it has been fit to the training data. 
#        Spark requires this fitted model be assigned to a new variable.
lr_fit = lr.fit(train_input)

# %%
#lr_fit- made from lr -now is a LogisticRegressionModel object, rather than just a LogisticRegression object.
type(lr_fit)
# Out:
# pyspark.ml.classification.LogisticRegressionModel

# %%
#The fitted model has a method that can evaluate it predicts the data it was fitted from.
lr_fit.summary.areaUnderROC
# Out:
# 0.6358776482407441

# %%
#Seeing how well the model does on a new dataset, namely Test, we have to pull out a Evaluation object from 
#pyspark.ml
evaluator = pyspark.ml.evaluation.BinaryClassificationEvaluator()

# %%
type(evaluator)
# Out:
# pyspark.ml.evaluation.BinaryClassificationEvaluator

# %%
#A lot of functions chained together. 1-Evaluate( 2-fitModel.transform( 3-rf.trainsform( 4-new data)))
test_auc = evaluator.evaluate(lr_fit.transform(rf.transform(test)))

# %%
type(test_auc)
# Out:
# float

# %%
#Test is just a .25 slice of the initial RDD. So it has to go through the 
test_input = rf.transform(test)

# %%
type(test_input)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
#I don't quite understand this one. I think the .select is making a new RDD
#.groupby is making a groupby table
#.pivot? I never feel comfortable with that one
#.counting something from this new pivoted table
#.show()!
(lr_fit.transform(test_input)
 .select('time', 'total_bill', 'size', 'label', 'probability', 'prediction')
 .groupby('prediction') # predicted == rows
 .pivot('label') # actual values are columns
 .count()
 .show())

# %% [markdown]
# Create a regression model to predict how many days late a case will be (i.e. predict num_days_late). Experiment with different combinations of features and different regression algorithms.
