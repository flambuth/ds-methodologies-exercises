# %%
# Wrangling
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# Exploring
import scipy.stats as stats

# Visualizing
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from sklearn.model_selection import learning_curve
# %matplotlib inline

# %%
import acquire
import summarize
import prepare

# %%
df = acquire.get_zillow_singles()

# %%
df.shape
# Out:
# (73596, 61)

# %%
df2 = acquire.get_real_zillow_singles()

# %%
df2.shape
# Out:
# (73424, 61)

# %%
len(df.parcelid.unique())
# Out:
# 73424

# %%
summarize.nulls_by_col(df).sort_values(by='pct_rows_missing')
# Out:
#                               num_rows_missing  pct_rows_missing
# id                                           0          0.000000
# assessmentyear                               0          0.000000
# roomcnt                                      0          0.000000
# regionidcounty                               0          0.000000
# rawcensustractandblock                       0          0.000000
# propertylandusetypeid                        0          0.000000
# propertycountylandusecode                    0          0.000000
# logerror                                     0          0.000000
# longitude                                    0          0.000000
# latitude                                     0          0.000000
# fips                                         0          0.000000
# calculatedfinishedsquarefeet                 0          0.000000
# transactiondate                              0          0.000000
# ...

# %%
#handles missing rows eleminates rows that have a missing portion higher than the threshold given as  the second 
#parameter.
new_df = prepare.handle_missing_columns(df, .5)

# %%
#as can be seen here, where there is no column that is missing more than .5 of their records
summarize.nulls_by_col(new_df)
# Out:
#                               num_rows_missing  pct_rows_missing
# id                                           0          0.000000
# parcelid                                     0          0.000000
# bathroomcnt                                  0          0.000000
# bedroomcnt                                   0          0.000000
# buildingqualitytypeid                    26830          0.364558
# calculatedbathnbr                           15          0.000204
# calculatedfinishedsquarefeet                 0          0.000000
# finishedsquarefeet12                       217          0.002949
# fips                                         0          0.000000
# fullbathcnt                                 15          0.000204
# heatingorsystemtypeid                    25270          0.343361
# latitude                                     0          0.000000
# longitude                                    0          0.000000
# ...

# %%
df2 = prepare.handle_missing_rows(df, .4)

# %%
summarize.nulls_by_row(df2).sort_values(by='num_cols_missing')
# Out:
#        pct_cols_missing  num_cols_missing
# 17897         30.645161                19
# 14681         30.645161                19
# 11559         32.258065                20
# 44051         32.258065                20
# 51713         32.258065                20
# 29370         32.258065                20
# 30646         32.258065                20
# 60238         32.258065                20
# 9105          32.258065                20
# 59193         32.258065                20
# 17715         32.258065                20
# 72266         32.258065                20
# 13920         33.870968                21
# 62659         33.870968                21
# 20658         33.870968                21
# 46932         33.870968                21
# 46633         33.870968                21
# 21072         33.870968                21
# 21973         33.870968                21
# 45945         33.870968                21
# 63677         33.870968                21
# ...
